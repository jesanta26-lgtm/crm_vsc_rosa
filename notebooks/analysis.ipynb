# %% [markdown]
# # Proyecto: crm_vsc_rosa
#
# ## Objetivo
# Describe aquí el objetivo del análisis.
#
# ## Descripción de los datos
# Explica brevemente qué contiene el dataset y qué preguntas quieres responder.

# %% [markdown]
# ## 1. Carga de librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Hola mundo 🚀")

# %% [markdown]
# ## 2. Carga de datos
# Ajusta la ruta y el nombre del archivo según tu proyecto.

# %%
# df = pd.read_csv('../data/dataset.csv')
# df.head()

# %% [markdown]
# ## 3. Exploración inicial de datos

# %%
# df.info()
# df.describe()
# df.isna().sum()

# %% [markdown]
# ## 4. Limpieza y preparación de datos

# %%
# df = df.dropna()
# df.head()

# %% [markdown]
# ## 5. Análisis exploratorio de datos (EDA)

# %%
# df['columna'].hist()
# plt.title('Distribución de la columna')
# plt.show()

# %% [markdown]
# ## 6. Análisis adicional

# %%
# df.groupby('categoria')['valor'].mean()

# %% [markdown]
# ## 7. Conclusiones
